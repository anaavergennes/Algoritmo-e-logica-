# %% [markdown]
# <a href="https://colab.research.google.com/github/anaavergennes/Algoritmo-e-logica-/blob/main/ExerciciosAlgoritmos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Adição")

a = float (input ("Insira um número:"))
b = float (input("Insira um número:"))

soma = a + b

print ("Adição:", soma)
# Out:
# Adição
# Insira um número:2
# Insira um número:2
# Adição: 4.0

# %%
print ("Subtração")

a = float (input ("Insira um número:"))
b = float (input("Insira um número:"))

subtracao = a - b

print ("Subtração:", subtracao)
# Out:
# Subtração
# Insira um número:6
# Insira um número:2
# Subtração: 4.0

# %%
print ("Multiplicação")

a = float (input ("Insira um número:"))
b = float (input("Insira um número:"))

multiplicacao = a * b

print ("Multiplicação:", multiplicacao)
# Out:
# Multiplicação
# Insira um número:2
# Insira um número:3
# Multiplicação: 6.0

# %%
print ("Divisão")

a = float (input ("Insira um número:"))
b = float (input("Insira um número:"))

divisao = a / b

print ("Divisão:", divisao)
# Out:
# Divisão
# Insira um número:12
# Insira um número:2
# Divisão: 6.0

# %%
print("Dobro e Triplo")

a = float(input("Insira um número:"))

dobro = a * 2
triplo = a * 3

print("Dobro:", dobro)
print("Triplo:", triplo)
# Out:
# Dobro e Triplo
# Insira um número:2
# Dobro: 4.0
# Triplo: 6.0

# %%
print("Antecessor e Sucessor")

a = float(input("Insira um número:"))

antecessor = a - 1
sucessor = a + 1

print("Antecessor:", antecessor)
print("Sucessor:", sucessor)

# %%
print("Perimetro do Retangulo")

base = float(input("Insira a base:"))
altura = float(input("Insira a altura:"))

perimetro = 2 * (base + altura)

print("Perimetro:", perimetro)
# Out:
# Perimetro do Retangulo
# Insira a base:5
# Insira a altura:2
# Perimetro: 14.0

# %%
print("Area do Retangulo")

base = float(input("Insira a base:"))
altura = float(input("Insira a altura:"))

area = base * altura
print("Area:", area)
# Out:
# Area do Retangulo
# Insira a base:10
# Insira a altura:10
# Area: 100.0
